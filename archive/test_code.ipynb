# %%
from bike_model import *
import matplotlib.pyplot as plt
import sympy as sp
import sympy.physics.mechanics as me

# %%
# eval_f01 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_Cf_Cr_x)
# eval_f02 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_Cf_Cr_z)
# eval_f03 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_Cr_O_x)
# eval_f04 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_Cr_O_z)
# eval_f05 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P1r_Cr_x)
# eval_f06 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P1r_Cr_z)
# eval_f07 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P3r_Cr_x)
# eval_f08 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P3r_Cr_z)
# eval_f09 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P1f_Cf_x)
# eval_f10 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P1f_Cf_z)
# eval_f11 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P3f_Cf_x)
# eval_f12 = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, r), r_P3f_Cf_z)

# %%
Cr.pos_from(O).express(N)

# %%
S.pos_from(Cr).express(N)

# %%
Q.pos_from(S).express(F), Q.pos_from(S).express(R), Q.pos_from(S).express(N)

# %%
Cf.pos_from(Q).express(R)

# %%
r_S_Cr_x = S.pos_from(Cr).dot(N.x)
r_S_Cr_z = S.pos_from(Cr).dot(N.z)

r_Q_S_x = Q.pos_from(S).dot(N.x)
r_Q_S_z = Q.pos_from(S).dot(N.z)

r_Cf_Q_x = Cf.pos_from(S).dot(N.x)
r_Cf_Q_z = Cf.pos_from(S).dot(N.z)


eval_steering_x = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, rr, rf), r_S_Cr_x)
eval_steering_z = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, rr, rf), r_S_Cr_z)

eval_fork_x = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, rr, rf), r_Q_S_x)
eval_fork_z = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, rr, rf), r_Q_S_z)

eval_trail_x = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, rr, rf), r_Cf_Q_x)
eval_trail_z = sp.lambdify((phi, theta, psi, delta, x_r, y_r, z_r, lr, lf1, lf2, rr, rf), r_Cf_Q_z)


subs = (0, 0, 0, 0, 500, 500, 355.6, 1000, 500, 100, 355.6, 355.6)

rear_wheel = (eval_f03(*subs), eval_f04(*subs))
front_wheel = (eval_f01(*subs), eval_f02(*subs))

rw_contact = (eval_f07(*subs), eval_f08(*subs))
fw_contact = (eval_f11(*subs), eval_f12(*subs))

steering = (eval_steering_x(*subs), eval_steering_z(*subs))
fork = (eval_fork_x(*subs), eval_fork_z(*subs))
trail = (eval_trail_x(*subs), eval_trail_z(*subs))

# %%
alist = [1,2,3,4,5]

alist[2] = alist[2] + 8
alist

# %%
def afunction():
    a = 1
    b = 2
    c = 3
    d = 4
    e = 'e'
    f = 'j'
    g = 9.81

    return [(a,b,c), 
            (d,e), 
            (f,g)]

tuple1, tuple2, tuple3 = afunction()
lista = afunction()

lista

# %%
N, R, F = sp.symbols('N, R, F', cls=me.ReferenceFrame)


R.orient_body_fixed(N, (psi, phi, theta), 'ZXY')
F.orient_axis(R, delta, R.z)

me.cross(R.y, F.y).dot(N.x)
me.cross(R.y, F.y).dot(N.z)

# %%
import random

lista_random = np.array([random.randint(0,10) for x in range(10)])
lista_random2 = np.array([random.randint(0,10) for x in range(10)])
print(lista_random)
print(lista_random2)

lista_random_mix = np.array([a-b if a < b else 0 for a,b in zip(lista_random, lista_random2)])

print(lista_random_mix)

lista5 = np.sqrt(lista_random)
print(lista5)

# lista3 = lista_random+lista_random2
# lista3

# %%
import sympy as sp
import sympy.physics.mechanics as me

# %%
N = me.ReferenceFrame('N')

O, P, Q, R = sp.symbols('O, P, Q, R', cls=me.Point)

O.set_pos(O, 0)
P.set_pos(O, 2*N.x + 2*N.z)
Q.set_pos(O, 4*N.x + 10*N.y)
R.set_pos(Q, 2*N.x + 2*N.z)

u1, u2, u3 = sp.symbols('u1, u2, u3')
v1, v2, v3 = sp.symbols('v1, v2, v3')
w1, w2, w3 = sp.symbols('w1, w2, w3')

u= u1*N.x + u2*N.y + u3*N.z
v= v1*N.x + v2*N.y + v3*N.z
w= w1*N.x + w2*N.y + w3*N.z

# subs1 = {u1: }

P.pos_from(O), R.pos_from(Q)

# %%
from utils import plot_mbd_model_2d
import numpy as np
import matplotlib.pyplot as plt

# bike_params = {
#     'lr': 140,
#     'lf1': 50,
#     'lf2': 10,
#     'rf': 75,
#     'rr': 75 
# }

bike_params = {
    'lr': 4,
    'lf1': 2,
    'lf2': 1,
    'rf': 1,
    'rr': 1 
}

x0_1 = np.array([
    np.deg2rad(0),
    np.deg2rad(-21.8014125), 
    np.deg2rad(0),
    np.deg2rad(0),
    0,
    0,
    2
])

x0_2 = np.array([
    np.deg2rad(0),
    np.deg2rad(-21.8014125), 
    np.deg2rad(0),
    np.deg2rad(0),
    8,
    500,
    2
])

fig, axs = plt.subplots()
plot_mbd_model_2d(axs, bike_params, x0_1, 'model')
plot_mbd_model_2d(axs, bike_params, x0_2, 'model')

axs.grid()
plt.xlim(-5, 20)
plt.ylim(-5, 20)
plt.plot()

# %%
a = 2

if a == 2: print(a+5)
